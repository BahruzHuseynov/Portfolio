# %% [markdown]
# <a href="https://colab.research.google.com/github/BahruzHuseynov/Portfolio/blob/main/TensorFlow2_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://media.geeksforgeeks.org/wp-content/uploads/20230410104038/Artificial-Neural-Networks.webp">

# %%
# Install the Kaggle API client
# !pip install -q kaggle

# Make a directory for the Kaggle API key
# !mkdir -p ~/.kaggle

# %%
from google.colab import files

# Upload kaggle.json file
uploaded = files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-62efd656-5da0-4d52-9880-b1f112656624" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62efd656-5da0-4d52-9880-b1f112656624">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d krishnaraj30/salary-prediction-data-simple-linear-regression
# !unzip salary-prediction-data-simple-linear-regression.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/krishnaraj30/salary-prediction-data-simple-linear-regression
# License(s): CC0-1.0
# salary-prediction-data-simple-linear-regression.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  salary-prediction-data-simple-linear-regression.zip
#   inflating: Salary Data.csv
#   inflating: Salary_Data.csv

# %%
# !kaggle datasets download -d ayyucek/automobile-dataset
# !unzip automobile-dataset.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ayyucek/automobile-dataset
# License(s): unknown
# ...
#   0% 0.00/1.18k [00:00<?, ?B/s]
# 100% 1.18k/1.18k [00:00<00:00, 1.86MB/s]
# Archive:  automobile-dataset.zip
#   inflating: Automobile_data.csv

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ### Dataset Loading

# %%
import pandas as pd

import tensorflow as tf
from tensorflow import keras
from keras import Sequential, layers

# %%
df = pd.read_csv("Experience-Salary.csv")
df.head()
# Out:
#    exp(in months)  salary(in thousands)
# 0       18.290293             16.521825
# 1       17.023407             11.666234
# 2       26.343613             23.167255
# 3       19.105834             20.877145
# 4       27.742516             23.166236

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X
# Out:
# 0      18.290293
# 1      17.023407
# 2      26.343613
# 3      19.105834
# 4      27.742516
#          ...
# 995    22.161741
# 996    32.266497
# 997    17.039030
# 998    25.222124
# 999    16.418028
# Name: exp(in months), Length: 1000, dtype: float64

# %%
model = Sequential([
    layers.Dense(1, input_shape=(1,), activation = 'linear'),
    layers.Dense(5, input_shape=(1,), activation = 'linear'),
    layers.Dense(1, input_shape=(1,), activation = 'linear')
])
model.compile(optimizer='sgd', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 2/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 3/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 4/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 5/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 6/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 7/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 8/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 9/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 11/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/50
# 29/29 [==============================] - 0s 2ms/step - loss: nan
# Epoch 13/50
# ...

# %% [markdown]
# # Multiple Linear Regression
