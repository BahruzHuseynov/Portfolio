# %% [markdown]
# # Problem Solving with Algorithms and Data Structures
# ## Release 3.0 - September 22, 2013
# ### Brad Miller, David Ranum

# %% [markdown]
# ### Prerequisites
# - Prior Python knowledge can be perfect (Control Flow, OOP and so on)

# %% [markdown]
# ## Chapter 1 - Introduction

# %% [markdown]
# The first chapter is just about what algorithm, computer science are and basics of Python programming.
#
# - Data types
# - Integer operators
# - String manipulations
# - Control Flow (if-else, for, while)
# - Lists, dictionaries and tuples
# - List comprehensions
# - Exception Handling
# - Functions

# %% [markdown]
# ## Chapter 2 - Algorithm Analysis

# %% [markdown]
# ## Chapter 3 - Basic Data Structures

# %% [markdown]
# <p style = "font-size: 18px">We will begin our study of data structures by considering four simple but very powerful concepts. Stacks, queues, deques, and lists are examples of data collections whose items are ordered depending on how they are added or removed. </p>
# <p style = "font-size: 18px">
# A stack, also known as a "push-down stack," is a linear data structure where new items are added and removed from the same end, typically referred to as the "top," while the opposite end is called the "base." This structure follows the <b>Last-In-First-Out (LIFO) </b> principle, meaning the most recently added item is the first to be removed. </p>

# %% [markdown]
# <img src = "https://techvidvan.com/tutorials/wp-content/uploads/sites/2/2021/06/Stack-normal-images01.jpg">

# %% [markdown]
# <img src = "https://sbme-tutorials.github.io/2020/data-structure-FALL/images/stack2.png">

# %% [markdown]
# <p style = "font-size: 18px"> Although in other languages, there are various modules to import different data structures, Python has been designed to easily build them based on the list methods. </p>

# %%
class Stack:
    def __init__(self):
        self.items = []
    
    def is_empty(self):
        return self.items == []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def peek(self):
        return self.items[-1]

    def size(self):
        return len(self.items)
    
    def display(self):
        for i in self.items[::-1]:
            print(i)

# %%
s = Stack()
print(s.is_empty())
s.push(4)
s.push("dog")
print(s.peek())
s.push(True)
print(s.size())
print(s.is_empty())
s.push(8.4)
print(s.pop())
print(s.pop())
print(s.size())
# Out:
# True
# dog
# 3
# False
# 8.4
# True
# 2

# %%
s.display()
# Out:
# dog
# 4

# %%
def par_checker(symbol_string):
    s = Stack()
    balanced = True
    index = 0
    
    while index < len(symbol_string) and balanced:
        symbol = symbol_string[index]
        if symbol == "(":
            s.push(symbol)
        elif s.is_empty():
            balanced = False
        else:
            s.pop()

    index = index + 1
    if balanced and s.is_empty():
        return True
    else:
        return False

# %%
print(par_checker('((()))'))
